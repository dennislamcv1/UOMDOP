# %% [markdown]
# # Module 1 Jupyter Lab
# This Jupyter notebook is a place to practice skills and concepts from Module 1.

# %% [markdown]
# ## Matrix operations review
#
# First, generate three NumPy arrays with the following properties:
#
# - $A$, a 5 by 5 array of randomly generated integers with values from 0 through 9.
# - $B$, a 1 by 5 array of randomly generated integers with values from 0 through 9.
# - $C$, a 5 by 2 array of randomly generated integers with values from 0 through 9.

# %%
import numpy as np
# A is a random 5 x 5 matrix
A = np.random.randint(0, 10, (5, 5))
# B is a random 1 x 5 matrix
B = np.random.randint(0, 10, 5)
# C is a random 5 x 2 matrix
C = np.random.randint(0, 10, (5, 2))

# %% [markdown]
# Next, translate each of the following calculations into code. Be mindful of which operators and NumPy functions you are using.

# %% [markdown]
# ### Calculation A
# Compute the element-wise product of A with itself.

# %%
# your code goes here

# %% [markdown]
# ### Calculation B
# Use broadcasting to calculate the element-wise product of A with B.

# %%
# your code goes here

# %% [markdown]
# ### Calculation C
# Calculate the matrix product of A with C.

# %%
# your code goes here

# %% [markdown]
# ### Calculation D
# Calculate the dot product of B with C.

# %%
# your code goes here.

# %% [markdown]
# ## Applications with text embeddings
# We will now revisit using language models to calculate the similarities between sequences of text. Below is a corpus (a collection of texts) that we will be embedding into a text vector space. This corpus is a selection of [science trivia facts compiled by the BBC](https://www.sciencefocus.com/science/fun-facts).

# %%
corpus = ["A cloud weighs around a million tonnes.",
          "Giraffes are 30 times more likely to get hit by lightning than people.",
          "Identical twins don't have the same fingerprints.",
          "Earth's rotation is changing speed.",
          "All the world's bacteria stacked on top of each other would stretch for 10 billion light-years.",
          "You can yo-you in space.",
          "Fish form orderly queues in emergencies.",
          "Most ginger cats are male.",
          "There's a planet made mostly from diamond.",
          "The biggest butterfly in the world has a 31 cm wingspan.",
          "The moon is shrinking.",
          "Flamingoes aren't born pink.",
          "Someone left a family photo on the Moon.",
          "Your brain burns 400-500 calories a day.",
          "You can't fold a piece of A4 paper more than 8 times.",
          "You can smell ants."
]

# %% [markdown]
# Following the example we covered in this week's video, create an array representing the embeddings of each sentence in the corpora. You will need to instantiate a model using the `sentence-transformers` library. As in the example from the video, use the `all-MiniLM-L6-v2` model to encode the corpus.

# %%
# your code goes here

# %% [markdown]
# Now, create a target sentence that we want to find "neighbors" of in the embedding vector space. A good example might be "Give me a fact about an animal."

# %%
# your code goes here.

# %% [markdown]
# Then:
#
# - Embed your target sentence,
# - Calculate the similarity of each sentence in the corpus to the target via the dot-product of the embeddings,
# - Rank the sentences in the corpora in order of similarity, in descending order. Your ranked list should therefore begin with the most similar sentence.

# %%
# your code goes here

# %% [markdown]
# ### Experiment with a different embedding model
# What if you had chosen a different embedding model for the texts? Would you still get similar results?
#
# First, choose another model available from the `SentenceTransformers` library, and then instantiate that model (you might give it a name like `modelB`). A [list of suggested models is here](https://sbert.net/docs/sentence_transformer/pretrained_models.html#original-models).

# %%
# your code goes here

# %% [markdown]
# Now, calculate new embeddings for the corpus and the target sentence (note that you will have to recalculate _both_!). Make sure to name these variables carefully, so they are distinct from the variables you used previously.

# %%
# your code goes here.

# %% [markdown]
# Now compare the embeddings produced by the two different models. Are they the same?

# %%
# your code goes here

# %% [markdown]
# _Use this markdown cell to explain if the embeddings are similar or different, and if they are different, what you notice._

# %% [markdown]
# ### Rerank similarities with the new model
# Using your new model, recalculate the similarity between each of the corpus sentences and your target sentence. Then rank the corpus sentences in order of descending similarity with the target.
#
# _Remember:_ you will need to encode both the corpus _and_ the target sentence with the new model before calculating the similarities!

# %%
# your code goes here

# %% [markdown]
# Did the rankings change at all? If they changed, what is different?

# %%
# your code goes here

# %% [markdown]
# _Use this markdown cell to reflect on any changes in the sentence rankings._
