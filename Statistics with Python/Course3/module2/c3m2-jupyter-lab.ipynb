# %% [markdown]
# # Module 2 Jupyter Lab
#
# This Jupyter notebook is a place to practice skills from this module.

# %% [markdown]
# ## Basic probability review
# Review the code notebook from the video lecture about basic probability. Then, write a function named `coin_flip()` that simulates flipping a fair coin _n_ times. The function should take as an argument _n_, an integer number of coin flips, and return an array of values representing the outcomes (where 1.0 is heads and 0.0 is tails.)

# %%
# your code goes here

# %% [markdown]
# Use your function to simulate 10 coin flips. Then calculate what percent of the coin flips are heads. Print out the result.

# %%
# your code goes here

# %% [markdown]
# Now, simulate 100 coin flips and calculate what percent of the coin flips are heads. Print out the result.

# %%
# your code goes here.

# %% [markdown]
# Finally, simulate 1000 coin flips and calculate what percent of the coin flips are heads. Print out the result.

# %%
# your code goes here

# %% [markdown]
# Create a new function named `loaded_coin_flip()`, which takes as arguments:
#
# - $n$, the number of coin flips to simulate, and
# - $p$, the probability of getting heads

# %%
# your code goes here

# %% [markdown]
# Use loaded_coin_flip() to simulate 100 coin flips where the probability of getting heads is 0.6.

# %%
# your code goes here

# %% [markdown]
# What proportion of flips came up heads?

# %%
# your code goes here

# %% [markdown]
# Based on this proportion of heads, do you think a person would be able to detect that the coin is unfair? Why?

# %% [markdown]
# _Use this markdown cell to answer the question._

# %% [markdown]
# ## Working with data-generating distributions in `scipy`
# During the video lectures, we interacted with a variety of different data-generated distributions provided by the `scipy` library. Review the [list of distributions](https://docs.scipy.org/doc/scipy/reference/stats.html). We will now use a combination of documentation and experimentation to learn about another, the Poisson distribution.
#
# First, refer to the [documentation page about the Poission distribution object in `scipy`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html#scipy.stats.poisson). Then answer the following questions:
#
# - Is this distribution continuous or discrete?
# - Does it have a probability density function or probability mass function?
# - What is the name of the shape parameter that can be passed to the Poission distribution object?

# %% [markdown]
# _Use this markdown cell to answer the questions above._

# %% [markdown]
# Generate 1000 samples from this distribution where the shape parameter is set to 1. Then, calculate some summary statistics about the generated samples:
#
# - What is the minimum value?
# - What is the maximum value?
# - What is the mean?
# - What is the median?
#
# You may also wish to plot the data using your preferred method, although this is optional.

# %%
# your code goes here

# %% [markdown]
# Now, use the Poisson distribution object to generate the following scenarios:
#
# - 10,000 randomly generated samples where the shape parameter is set to 1.
# - 10,000 randomly generated samples where the shape parameter is set to 10.
# - 10,000 randomly generated samples where the shape parameter is set to 100.

# %%
# your code goes here

# %% [markdown]
# What is different about the data generated under each of these conditions? You can explore this by making visualizations, calculating summary statistics about the data, or something else.

# %%
# your code goes here

# %% [markdown]
# _Use this markdown cell to explain your findings in a few sentences._
