# %% [markdown]
# # Module 3 Jupyter Lab
# This notebook is a place to practice skills from Module 3.

# %% [markdown]
# ## Generating data
# Generate 100 random numbers from a normal distribution with mean 5 and standard deviation 1. Make sure to set a random seed so that this computation is reproducible. Use the `stats` library to generate the data, not `numpy`.

# %%
# your code goes here.

# %% [markdown]
# ## Investigate your data
#
# ### Summary statistics
# Calculate the following summary statistics about the data you generated:
#
# - What is the mean?
# - What is the median?
# - What is the standard deviation?
#
# Your code should not only calculate these values, but also print the result for a reader ("The mean is..."; "The median is...").

# %%
# your code goes here

# %% [markdown]
# Do the mean and standard deviation you calculated match the parameters you used to generate the data? Note any differences and write a sentence or two about why you think this happened.

# %% [markdown]
# _Use this markdown cell to write your answer._

# %% [markdown]
# ### Confidence intervals
# Calculate the following confidence intervals on the data you generated using the percentile method:
#
# - 90%
# - 95%
# - 99%
#
# Your code should return not only the correct answers, but also print them for a reader ("The 90% confidence interval spans from .... to ...").

# %%
# your code goes here

# %% [markdown]
# Now, calculate the following confidence intervals using the theoretical properties of the normal distribution:
#
# - 68%
# - 95%
# - 99%
#
# Once again, your code should not only return the correct answers, but print them in a legible form for a reader.

# %%
# your code goes here

# %% [markdown]
# ## Using data to contextualize observations
# Calculate z-scores for the following values. In your calculation, use the mean and standard deviation that you calculated earlier from your 100 data points.
#
# - 6
# - 9.5
# - 4
# - 2

# %%
# your code goes here

# %% [markdown]
# Based on the z-scores you calculated, which of those observations would you consider most surprising?

# %% [markdown]
# _Use this markdown cell to write your answer._
