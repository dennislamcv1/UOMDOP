# %% [markdown]
# # Week 2 Challenges

# %%
import numpy as np

# %% [markdown]
# ## Challenge 01
#
# ### 1.1 Create array [1 point]
#
# Call the appropriate NumPy function that can return a one-dimensional array comprising twenty (`20`) zero (`0`) elements of type `int`. Assign the variable `mads` to the return value of the function call.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 1.2 Mutate elements [1 point]
#
# Starting with the first array element in `mads`, replace _every other_ zero (`0`) element with the integer one (`1`). Employ __array slicing__ to accomplish the task.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 02
#
# ### 2.1 Reshape array [1 point]
#
# Call the appropriate `mads` array method or NumPy function that can return a version of `mads` converted to a two-dimensional array comprising four (`4`) rows and five (`5`) columns. Assign the variable `mads_matrix` to the new multi-dimensional array.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.2 Concatenate arrays [1 point]
#
# Create a one-dimensional array comprising five (`5`) zero (`0`) elements of type `int`. Assign the variable `zeros` to the return value of the functon call. Then concatenate `mads_matrix` and `zeros` such that the `zeros` array comprises the last row of the new array. Assign the variable `mads_matrix` to the return value of the function call.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.3 Mutate array element [1 point]
#
# Access the last row in the `mads_matrix` array and replace the third (`3rd`) element with the integer `1`. Employ __array indexing__ to accomplish the task.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 03
#
# ### 3.1 Broadcast a scalar [1 point]
#
# Add the scalar value `0.05` to each array element in `mads_matrix`. Point the variable `mads_matrix` to the new array returned by the broadcasting operation.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.2 Broadcast an array [1 point]
#
# Create a two-dimensional `5`x`1` array named `overlay` consisting of the following values:
#
# ```python
# array([[0. ],
#        [0.2],
#        [0.4],
#        [0.6],
#        [0.8]])
# ```
#
# Next, add `overlay` to `mads_matrix`. Point the variable `mads_matrix` to the new array returned by the broadcasting operation.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 04
#
# ### 4.1 Compute summary statistics [1 point]
#
# Compute the minimum value, maximum value, mean, standard deviation, and sum of `mads_matrix`. Source the values for the new array from `mads_matrix`. Assign the values to a dictionary named `mads_matrix_stats` structured as follows:
#
# ```python
# {
#     "min": < min value >,
#     "max": < max value >,
#     "mean": < mean value >,
#     "std": < standard deviation >,
#     "sum": < sum value >
# }
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.2 Compute column-wise summary statistics [1 point]
#
# Next, compute `mads_matrix` column-wise summary statistics (i.e., min, max, mean, std, sum). Store the arrays in a nested dictionary in `mads_matrix_stats`. Employ the same keys specified in section `4.1` for the new dictionary. Map the nested dictionary to key named "column_wise".
#
# ```python
# {
#     ...,
#     "column_wise": < {...} >
# }
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.3 Compute row-wise summary statistics [1 point]
#
# Finally, compute the `mads_matrix` row-wise summary statistics (i.e., min, max, mean, std, sum). Store the arrays in a nested dictionary added to `mads_matrix_stats`. Employ the same keys specified in section `4.1` for the new dictionary. Map the nested dictionary to a key named "row_wise".
#
# ```python
# {
#     ...,
#     "column_wise": < {...} >,
#     "row_wise": < {...}
# }
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 05
#
# ### 5.1 Apply a boolean array mask [1 point]
#
# Create an array comprising `mads_matrix` elements found in either the `5th` __or__ `95th` percentiles. Source the values for the new array from `mads_matrix`. Name the new array `outliers_mask`.
#
# After creating `outliers_mask` employ it to select the elements in `mads_matrix` by applying the boolean mask. Name the one-dimensional array returned by the masking operation `outliers`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 06
#
# ### 6.1 Sort row-wise (in-place) [1 point]
#
# Perform a **in-place** row-wise sort of `mads_matrix` in ascending order.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 6.2 Flatten then sort in descending order [1 point]
#
# Flatten `mads_matrix` and then sort the list elements in descending order. Do not perform an in-place sort. Return a new array flattened and sorted in descending order. Assign the variable `mads_matrix_flat` to the new array.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 07
#
# ### 7.1 `NaN` placeholders array [1 point]
#
# Every NumPy array possesses a shape attribute. Use that knowledge to create a new one-dimensional array based on a list of `NaN` elements with a length equal to the number of elements that comprise the second dimension of the `mads_matrix` array. Name the new array "placeholders". Consider leveraging a list comprehension to accomplish this task.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 7.2 Add placeholders [1 point]
#
# Combine the `mads_matrix` and `placeholders` arrays such that resulting new array is structured as follows:
#
# ```python
# array(
#     [
#         [0.05, 0.05, 1.05, 1.05, 1.05,  nan],
#         [0.25, 0.25, 0.25, 1.25, 1.25,  nan],
#         [0.45, 0.45, 1.45, 1.45, 1.45,  nan],
#         [0.65, 0.65, 0.65, 1.65, 1.65,  nan],
#         [0.85, 0.85, 0.85, 0.85, 1.85,  nan]
#     ]
# )
# ```
#
# Point the label `mads_matrix` to the new array. Consider carefully the shapes of the two arrays before embarking on this task.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell
