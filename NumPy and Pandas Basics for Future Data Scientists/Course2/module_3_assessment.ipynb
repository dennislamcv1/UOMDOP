# %% [markdown]
# # Module 3 Challenges

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Challenge 01
#
# ### 1.1 Create a Series [1 pt]
# Create a pandas Series named `fruits` with the following elements: 'apple', 'banana', 'cherry', 'date', 'elderberry'.

# %%
fruits = None 

# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 1.2 Create a Series with an Index [1 pt]
# Create another Series named `scores` with the following data and index:
#
# Data: [85, 92, 78, 95, 88]
#
# Index: ['Sonja', 'Jason', 'Sahar', 'Nelson', 'Asya']

# %%
scores = None
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 1.3 Access elements in a Series with `.loc` [1 pt]
# Access Nelson's score using `.loc` and save it to the variable `nelson_score`.

# %%
nelson_score = None

# YOUR CODE HERE
raise NotImplementedError()
type(nelson_score)

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 1.4 Access elements in a Series with `.iloc` [1 pt]
# Access the score of the second person in the series using `.iloc` and save it to the variable `second_person_score`.

# %%
second_person_score = None 

# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 02
#
# ### 2.1 Create a DataFrame [1 pt]
# Create a DataFrame named `student_data` with the following columns and values:
#
#  - Name: ['Sonja', 'Jason', 'Sahar', 'Nelson', 'Asya']
#  - Age: [22, 47, 31, 19, 24]
#  - Major: ['Math', 'Physics', 'Chemistry', 'Literature', 'Computer Science']
#  - GPA: [3.8, 3.9, 3.7, 3.6, 4.0]
#
#  The column names in the DataFrame should be capitalized as shown above.

# %%
student_data = None

# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.2 Add a new column [1 pt]
# Add a column to the `student_data` called `Year` with the values [2, 2, 3, 1, 4].

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.3 Drop a column [1 pt]
# Drop the column `Name` from the `student_data` DataFrame (note: this might be one step we would take towards _anonymizing_ a dataset).

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.4 Drop a row [1 pt]
# Drop the student whose index is 3 from `student_data`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 03
#
# ### 3.1 Inspect a DataFrame for understanding [2 pts]
# Read the DataFrame `penguins` by running the code in the cell below.

# %%
penguins = sns.load_dataset('penguins')

# %% [markdown]
# Calculate the following values:
#
# - the number of rows in `penguins` and save this as `penguin_rows`
# - the number of columns in `penguins` and save this as `penguin_columns`
# - the names of the columns in `penguins` and save this as `penguin_column_names`
# - the first 10 rows of `penguins` and save this as `penguin_first_ten_rows`
# - the second to last row of `penguins` and save this as `penultimate_penguin`

# %%
penguin_rows = None
penguin_columns = None
penguin_column_names = None
penguin_first_ten_rows = None
penultimate_penguin = None

# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 04
#
# ### 4.1 Use `apply` on a DataFrame [1 pt]
# Use `apply` to transform the values in the `species` column of `penguins` to lowercase.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.2 Write a custom function to transform data [1 pt]
# Write a function `grams_to_ounces` that converts grams to ounces. For this calculation, use the conversion factor of 1 gram to 0.035 ounces.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.3 `apply` a custom function to a DataFrame [1 pt]
# Create a new column in `penguins`, `body_mass_ounces`, that is the result of passing the column `body_mass_g` through your custom function `grams_to_ounces`. You should use the `apply` method in pandas to do this.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## Challenge 05
#
# ### 5.1 Filter a DataFrame by one condition [1 pt]
# Create a new DataFrame, `biscoe_penguins`, that contains only penguins that live on Biscoe Island.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.2 Filter a Dataframe by multiple conditions [1 pt]
# Create a new DataFrame, `big_dream_penguins`, that contains penguins who meet all of the following criteria:
#
# - They live on Dream Island
# - They weigh more than 4000 grams
# - Their flipper length is more than 200 mm

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.3 Count missing data [1 pt]
# Count how many rows in `penguins` are missing data in the column `body_mass_g` and save this value as `n_missing_mass`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.4 Fill missing data with a fixed value [1 pt]
# Replace any missing values in the columns `species` and `sex` with the string 'unknown'.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.5 Fill missing data with a mean value [1 pt]
# Calculate the mean value of `bill_length_mm` and assign it to the variable `mean_bill_length`. Then fill in any missing observations with the mean.

# %%
mean_bill_length = None

# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell
