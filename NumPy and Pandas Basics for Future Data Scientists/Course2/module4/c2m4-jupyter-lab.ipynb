# %% [markdown]
# # Module 4 Jupyter Lab
# This notebook is a place to review and practice skills from Module 4, using pandas to manipulate data objects.

# %%
import pandas as pd

# %% [markdown]
# We will be exploring a dataset of movie ratings offered by users of the Movie Lens website. This dataset is created and maintained by the GroupLens Research group at the University of Minnesota. Familiarize yourself with the official [dataset description first](https://files.grouplens.org/datasets/movielens/ml-latest-small-README.html), then examine the datasets using your preferred pandas methods.

# %%
ratings = pd.read_csv('data/movielens/ratings.csv')
movies = pd.read_csv('data/movielens/movies.csv')

# %%
# it is recommended you use this space to examine the DataFrames before moving on.

# %% [markdown]
# ## Merging DataFrames
# Merge the `movies` and `ratings` DataFrames on `movieId`.

# %%
# your code goes here

# %% [markdown]
# ## Understanding movie ratings
# What are movies in the dataset have the highest average rankings? Find all the movie titles whose average rating is a perfect score of 5.0.
#
# Note that you may need to use several steps to answer this question.

# %%
# your code goes here.

# %% [markdown]
# How many unique ratings do each of these top-rated movies have? Again, it may take several steps to answer this.

# %%
# your code goes here

# %% [markdown]
# ## Understanding movie raters

# %% [markdown]
# How many unique individuals contributed a movie rating to the dataset?

# %%
# your code goes here

# %% [markdown]
# Do some users contribute higher ratings, on average, than others? Calculate the average rating associated with each unique user.

# %%
# your code goes here.

# %% [markdown]
# Make a DataFrame representing reviews from users who have contributed more than 100 reviews.

# %%
# your code goes here

# %% [markdown]
# ## Transforming data
# Currently, the `movies` DataFrame has a column representing the genre of movies. Genres are separated by a `|` symbol.

# %%
movies.genres.head()
# Out:
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# 2                                 Comedy|Romance
# 3                           Comedy|Drama|Romance
# 4                                         Comedy
# Name: genres, dtype: object

# %% [markdown]
# First, write a function `genre_formatter()` that takes movie genres in their current form and transforms them into lowercase, comma-separated lists.
#
# That means that if `genre_formatter()` receives the input "Comedy|Romance", it should return "comedy, romance".

# %%
# your code goes here

# %% [markdown]
# Use the function `genre_formatter()` to transform the elements in the `genre` column of `movies`.

# %%
# your code goes here

# %% [markdown]
# Make a new DataFrame, `comedies`, containing user ratings and movie titles for movies where "comedy" is given as a genre label.

# %%
# your code goes here
