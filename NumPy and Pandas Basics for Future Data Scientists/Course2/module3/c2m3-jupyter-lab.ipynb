# %% [markdown]
# # Module 3 Jupyter Lab
# This notebook is a place to practice applying the techniques from Module 3:
#
# - Instantiating, inspecting, and understanding pandas data objects like Series and DataFrames
# - Transforming pandas objects with custom functions
# - Selecting elements of DataFrames by column and row values
# - Handling missing data in pandas

# %%
import pandas as pd
from sklearn import datasets

# %%
houses_download = datasets.fetch_california_housing()
houses = pd.DataFrame(houses_download.data, columns=houses_download.feature_names)
median_home_price = pd.Series(houses_download.target, name='median_home_price')

# %% [markdown]
# ## Familiarize yourself with the California Housing dataset
#
# First, take a look at the [data description](https://scikit-learn.org/1.5/datasets/real_world.html#california-housing-dataset).
#
# Then, using any of the techniques learned this week, answer the following questions. Note that these questions follow a line of inquiry that a data professional might use to understand a new dataset.
#
# #### 1. Is `houses` a DataFrame or a Series object?

# %%
# your code goes here

# %% [markdown]
# _Write your answer in this markdown cell._

# %% [markdown]
# ### 2. How many columns and rows are in `houses`?

# %%
# your code goes here

# %% [markdown]
# _Write your answer in this markdown cell._

# %% [markdown]
# ### 3. What data types are in `houses`?
# Find a way to display the data type for each column in `houses`.

# %%
# your code goes here

# %% [markdown]
# ### 4. What do some rows in `houses` look like?
# Find a way to display the first 15 rows.

# %%
# your code goes here

# %% [markdown]
# Now, display the _last_ 15 rows.

# %% [markdown]
# ### 5. What does one row in `houses` represent?
# Using your observations so far, plus the data documentation, describe in a sentence or two what a single row represents.

# %% [markdown]
# _Your answer goes here._

# %% [markdown]
# ### 6. How many missing values are there?
# Using any method you like, count how many missing values are present in `houses`.

# %%
# your code goes here

# %% [markdown]
# ## Manipulating data in pandas
#
# ### Changing a data type
# Thinking about the variables in this dataset, you might have noticed that one column - `population` - can only be whole numbers (think about why).
#
# Using `map()` or `apply()`, transform  the column `population` to an integer data type.
#
# _Very important!_ Your result should modify `houses`, not make a copy. How can you confirm this has happened?

# %%
# your code goes here

# %% [markdown]
# ### Transforming units
# Now consider the variable `median_home_price`. Using any functions you like, familiarize yourself with this object. It is recommended you consider questions like:
#
# - What data type is this?
# - What shape is it?
# - What are some typical values?
#
# Below, show some code that helps you inspect `median_home_price`.

# %%
# your code goes here

# %% [markdown]
# According to the data documentation, the values in `median_home_price` are in units of the _hundreds of thousands of dollars_. If we want to convert this value  to dollars, we need to multiply each element by 100,000.
#
# Create a new variable, `median_home_price_dollars`, representing the median home prices in dollars. This variable should be a Series object.

# %%
# your code goes here

# %% [markdown]
# ### Add a column
# This dataset was conceived as a modeling problem--the authors were interested in predicting the median home price for a census group(`median_home_price`) using other measurements (`houses`). For the purpose of understanding the data, rather than making a prediction, we might wish to see all these values together.
#
# Add `median_home_price_dollars` as a new column to `houses`.

# %%
# your code goes here

# %% [markdown]
# ### Drop columns
# Drop the columns representing latitude and longitude of a census group (check the data description if you're unsure which column names these are).
#
# _Important:_ Once again, be sure that you modify the object bound to `houses`, not a copy!

# %%
# your code goes here.

# %% [markdown]
# ### Filter the data
# Create a new DataFrame, `historic_blocks`, which includes only census blocks where the median house age for the district is _above average_ for this dataset.
#
# In other words, you will have to do two calculations:
#
# - First, find the average value of median home age in this dataset.
# - Then, filter `houses` for only rows whose median home age exceeds this value.

# %%
# your code goes here

# %% [markdown]
# Create a new DataFrame, `big_house_blocks`, representing census blocks where both of the following conditions are met:
#
# - There are on average 3 or more bedrooms.
# - There are on average 5 or more rooms.

# %%
# your code goes here
