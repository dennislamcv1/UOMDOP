# %% [markdown]
# # Module 1 Jupyter Lab
# This notebook provides opportunities to practice using the techniques covered in Module 1:
#
# - Creating NumPy arrays
# - Accessing NumPy array attributes
# - Slicing and indexing arrays
# - Dealing with missing data in arrays
# - Basic arithmetic operations with arrays

# %%
import numpy as np
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating arrays
# Make a NumPy array with 5 rows and 5 columns, filled with randomly generated integers.

# %%
# your code goes here

# %% [markdown]
# Make a NumPy array that corresponds to the following matrix:
#
# $\begin{bmatrix} 1.0 & 2.0 & 3.0 \\\ 2.0 & 4.0 & 6.0  \end{bmatrix} $

# %%
# your code goes here

# %% [markdown]
# Make a NumPy array with 10 rows and 10 columns. On the diagonal, every element should be 1. Elements not on the diagonal should be 0, with one exception: the element at index [2,4] should be 100.

# %%
# your code goes here

# %% [markdown]
# ## Working with data in arrays
# Let's load in a real example of data stored in a NumPy array. You'll see this again in the graded assessment for this module: it's a sample from a dataset of hand-written digits, stored as images (the [MNIST dataset](https://en.wikipedia.org/wiki/MNIST_database)).

# %%
digits = load_digits()
sample_img = digits.images[14]
plt.matshow(sample_img, cmap = "gray_r")

# %% [markdown]
# Answer the following questions about `sample_img` (use code in the block below, but also write your answers as text in the following Markdown cell):
#
# - 1. What size is `sample_img`?
# - 2. What shape is `sample_img`?
# - 3. What data-type is `sample_img`?

# %%
# your code goes here

# %% [markdown]
# Your answers to questions 1-3 goes here.

# %% [markdown]
# ### Indexing and slicing arrays
# Try to make each of the following subsets of `sample_img` with slicing and indexing.
#
# Begin by get the second row of `sample_img`. Save this to a new variable.

# %%
# your code goes here

# %% [markdown]
# Create a new variable containing the final two columns of `sample_img`.

# %%
# your code goes here

# %% [markdown]
# Create a Boolean mask representing the elements in `sample_img` that are larger than 0.

# %%
# your code goes here

# %% [markdown]
# Using the Boolean mask, return the elements of `sample_img` that are larger than 0.

# %%
# your code goes here.

# %% [markdown]
# ## Working with missing values
# The code below will generate an array `time_series` with a number of missing values (NaNs). Run the code to create `time_series` and then answer the following questions.

# %%
rng = np.random.default_rng(1)
time_series = rng.random((1,1000))
time_series.ravel()[np.random.choice(time_series.size, int(time_series.size*0.1), replace=False)] = np.nan

# %% [markdown]
# How many missing values are there in the array `time_series`?

# %%
# your code goes here

# %% [markdown]
# Fill in the missing values with 0.

# %%
# your code goes here

# %% [markdown]
# ## Arithmetic
# Finally, let's practice arithmetic with some more NumPy arrays from the MNIST dataset. Doing arithmetic with arrays can correspond to ways of processing images (or sound files, or any other data type that can be stored in an array). It's strongly recommended to try plotting the outputs of each of the following computations with the included `matplotlib` code.

# %%
img_a = digits.images[0]
img_b = digits.images[1]

# Code to plot one array
plt.matshow(img_a, cmap = "gray_r")

# %% [markdown]
# Before we begin, inspect the two arrays. Which hand-written digits do you think they correspond to?

# %% [markdown]
# First, add `img_a` and `img_b` (this corresponds to super-imposing the two drawings). Plot the result.

# %%
# your code goes here

# %% [markdown]
# Now substract `img_b` from `img_a` and plot the result.

# %%
# your code goes here

# %% [markdown]
# Finally, multiply the two images and plot the result (if you are familiar with image editing programs like Photoshop, you may have experienced the ["multiply" blending mode](https://en.wikipedia.org/wiki/Blend_modes#Multiply)- we will be implementing a simple form of it here)

# %%
# your code goes here

# %% [markdown]
# ## Bonus challenge
# The "multiply" blend mode above takes the product of two images. There is also a blend mode called "Screen", which does the opposite of multiplying. The formula is as follows:
#
# $f(a,b) = 1 - (1 - a)(1 - b)$
#
# where $a$ and $b$ are two arrays representing images. In order for this formula to work, the arrays first need to be _normalized_, or scaled, so that the maximum value in the arrays is 1.
#
# Can you implement this blend mode with `img_a` and `img_b`?

# %%
# your code goes here
