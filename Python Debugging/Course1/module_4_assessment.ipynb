# %% [markdown]
# # Module 4 Challenges
#
# ### Paul Resnick's publication citation history: Counting citations

# %% [markdown]
# This notebook focuses on the citation history of publications authored or coauthored by Professor
# Paul Resnick. You are tasked with identifying the top five most cited publications, the
# publications with the highest citation counts within `n` years after publication, and the
# publications with the highest year-over-year avaerage increase in citation counts. You will
# __implement functions__ as well as __debug errors__ lurking in the existing code.

# %%
import json
import numpy as np

from pathlib import Path

# %% [markdown]
# ## 1.0 Retrieve the data
#
# The JSON file `data-resnick_citations-v1p3.json` contains an array of JSON objects, each of which
# represents a publication authored or coauthored by Paul. The data was sourced from the
# [Web of Science](https://clarivate.com/academia-government/scientific-and-academic-research/research-discovery-and-referencing/web-of-science/).
# Originally, each publication comprised `50` name-value pairs. However, each publication has been
# "thinned" by dropping name-value pairs not required for the analysis. The following name-value pairs
# are retained:
#
# * Publication title
# * Authors
# * Source title
# * Publication year
# * Total number of citations
# * Annual average number of citations since publication
# * Citation counts per year, 1992-2023 (represented as a list of nested dictionaries)
#
# The code below deserializes the JSON document into a list of dictionaries named `publications` by
# instantiating an instance of `pathlib.Path` before passing the `path` object to the built-in function
# `open()` embedded in a `with` statement.

# %%
parent_path = Path("__file__").resolve().parent
filepath = parent_path.joinpath("data", "data-resnick_citations-v1p3.json")

with open(filepath, "r", encoding="utf-8") as file_obj:
    publications = json.load(file_obj)

print(f"\nPublications (n={len(publications)})")

# %% [markdown]
# ### 1.1 Variable names
#
# A number of variable names in this notebook leverage the following abbreviations. The naming
# strategy is to strike a balance between brevity and readability:
#
# * `avg`: average
# * `cits`: citations
# * `pub`: publication
# * `pubs`: publications
# * `umsi`: University of Michigan School of Information

# %% [markdown]
# ## 2.0 Review the data
#
# Get to know the `publications` list of nested dictionaries.
#
# ### 2.1 List of keys [1 pt]
#
# Access the first publication's keys,
# convert the `dict_keys` object to a list, and assign the list to a variable named `keys`. The `keys`
# will come in handy when working with each of the publication dictionaries. Then familiarize yourself
# with the period under review as well as the structure of the data, particularly with respect to each
# publication's annual citation counts.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.2 Period under review [1 pt]
#
# Accessing one of the publications returns a list of year values stored in the "Citations" list
# of nested dictionaries. In the code below the list returned is assigned to the variable named `years`.

# %%
years = [citation["Year"] for citation in publications[0]["Citations"]]
print(f"years = {years}")

print(f"\nmin year = {min(years)}, max year = {max(years)}")

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.3 Citation counts [1 pt]
#
# Loop over the `publications` list, access each "Total Citations" value, and compute the sum of "Total
# Citations" for all publications. Assign the sum to a variable named `total_cits`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## 3.0 Analysis: top five most cited publications
#
# Professsor Resnick is well known for his pioneering work on recommender systems. These systems combine data analysis, machine learning, and user behavior patterns to offer users personalized suggestions or services. Recommender systems are now a ubiquitous feature of e-commerce websites, streaming services, and social media platforms. Paul is also known for his work on reputation systems, social computing, and online communities.
#
# ### 3.1 Top five [1 pt]
#
# The code below returns Paul's top 5 most cited publications.

# %%
# Top 5 most cited publications
top_5_pubs = sorted(publications, key=lambda x: -x["Total Citations"])[:5]

print(top_5_pubs[-1]["Title"])

# %%
# hidden tests are within this cell

# %% [markdown]
# Perhaps not surpisingly, articles on recommender systems and reputation systems dominate Paul's top 5 most cited publications. Taken together, these five publications account for over two thirds of the total citations generated by Paul's coauthored publications.

# %%
top_5_total_cits = sum([publication["Total Citations"] for publication in publications[:5]])

print(f"\nTotal citations (top 5 publications) = {top_5_total_cits}")
print(f"\nTotal citations (all publications) = {total_cits}")

# Percentage of total citations
top_5_cits_pct = round((top_5_total_cits / total_cits), 2)

print(f"\nPercentage of total (top 5 publications) = {top_5_cits_pct}%")

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.2 Recommender/Reputation Systems vs all the rest [1 pt]
#
# Paul's most cited publication is a `1997` article entitled "Recommender systems", coauthored with H.
# R. Varian, and published in the journal _Communications of the ACM_. The publication has been cited
# `1,865` times between `1997` and `2023`. Paul's second most cited publication discusses reputation
# systems that permit user communities to rate members in order to build trust networks. It's been
# cited `1,130` times since its publication in `2000`.
#
# Compare the citation history of these two publications against all other publications authored or
# coauthored by Paul. Loop over the `publications` list. Inside the loop block implement a conditional statement that can identify the __top two (`2`)__ most cited publications. Assign a new key-value pair to each publication encountered. If the publication is one of the top two most cited publications, add the following key-value pair:
#
# `"Group": "top_02"`
#
# Otherwise, add the following key-value pair:
#
# `"Group": "other"`
#
# After adding the new key-value pair to each publication, remember to add "Group" to the `keys` list. The "Group" will be used to bin the publications in the stacked
# bar chart.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ## 4.0 Analysis: first `n` years citation counts
#
# One advantage these two publications possess over publications published during, say, the last ten
# years, is the longer time interval available in which to accumulate citations. Perhaps other
# publications exist that have been cited more frequently within, say, the first five or seven years
# _after_ the year of publication. That might tell us something about their likely impact on the
# scholarly community.
#
# ### 4.1 Implement `get_publication_citation_counts()` [1 pt]
#
# Implement the function `get_publication_citation_counts()` to count the number of citations accrued
# by each publication during the specified n-years _following_ the year of publication. Given that a
# publication could appear in any of the twelve months of a given year, only complete years are to be
# considered. For example, if a publication was published in the year `2020`, citation counts are
# tallied starting in the year `2021` _not_ `2020`.
#
# Review the function's docstring to better understand the task it is to perform, the parameters it
# defines, and the return value it computes.

# %%
def get_publication_citation_counts(publications, max_pub_year, n_years=5):
    """Returns a list of dictionaries that provide publication citation counts accrued during the
    specified < n_years > interval. Each interval commences in the year following a publication's
    date of publication. This is to ensure that only complete years are considered. Additionally,
    only publications published during or before the specified < max_pub_year > are evaluated. All
    others are ignored.

    Each dictionary added to the list returned to the caller contains the following key-value pairs:

    {
        title: < publication title >
        pub_year: < publication year >
        interval: < n years interval (e.g., "2015-2023") >
        citations: < citations total for the specified interval >
    }

    Parameters:
        publications (list): nested list of publications
        max_pub_year (int): latest publication year to be evaluated
        n_years (int): number of years to include in the interval

    Returns:
        list: list of dictionaries
    """

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.2 First five years [1 pt]
#
# Now that the functions `get_publication_citation_counts()` and `write_json()` are implemented, let's explore
# the possibility that other publications authored or coauthored by Paul Resnick are on track to
# garner as many citations, if not more, than the number of citations accrued by the recommender
# systems and reputation system articles.
#
# Call the function `get_publication_citation_counts()` and pass it the arguments `publications`, `2018`, and
# `5`. Given that the dataset is limited to the period `1992` to `2023`, only publications published
# between `1992` and `2018` will be evaluated.
#
# The function call will return a list of nested dictionaries that contain publication citation counts
# for the first five (`5`) full years _after_ publication. Assign the return value to a variable named
# `cits_first_5_yrs`.
#
# Next, sort the list of dictionaries by "citations", "pub_year" and "title" in the order specified:
#
# 1. "citations" (descending order)
# 2. "pub_year" (descending order)
# 3. "title" (ascending order)
#
# Then call the built-in `print()` function and inspect the first five dictionaries in the sorted
# list.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 4.3 A change at the top
#
# Two publications' citation counts exceed the number of citations accrued by Paul's
# "Recommendation systems" and "Reputation systems" articles during the first five (`5`) full years
# after publication:
#
# * Z. Zhao, P. Resnick, and Q. Mei, ["Enquiring Minds: Early Detection of Rumors in Social Media from Enquiry Posts"](https://dl.acm.org/doi/10.1145/2736277.2741637), WWW '15: Proceedings of the 24th International Conference on World Wide Web (2015), pp. 1395 - 1405.
#
# * P. Resnick, R. Zeckhauser, J. Swanson, and K. Lockwood, ["The value of reputation on eBay: A controlled experiment"](https://link.springer.com/article/10.1007/s10683-006-4309-2), Experimental Economics, vol. 9 (2006), pp. 79-101.
#
# ### 4.4 Write to file [1 pt]
#
# Write the list `cits_first_5_yrs` to a JSON file named `stu-resnick-citations-first_5_yrs.json`.
# Utilizing a `pathlib.Path` object to represent the filepath is recommended but not required. Save the
# file to the `data` directory.
#
# Check your output against the fixture data file named `fxt-resnick-citations-first_5_yrs.json`. The two files _must_ match line for line.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# **Note:** If you would like, explore calling `get_publication_citation_counts()` with varying number of years to compare results.

# %% [markdown]
# ## 5.0 Year-over-year rate of change
#
# The year-over-year rate of change in citation counts might prove a useful metric for evaluating the
# impact of a publication. A publication that garners a large number of citations in a short period of
# time might be considered more impactful than a publication that accumulates citations at a slower
# rate.
#
# ### 5.1 Implement `get_citation_change_rates()` [1 pt]
#
# First, implement the function `get_citation_change_rates()`. This function computes the
# year-over-year rate of change in citation counts for a given publication and stores the values in a
# list. Review the function's docstring to better understand the task it is to perform, the parameters
# it defines, and the return value it computes.
#
# The rate of change is computed as the difference between the current year's citation count and the
# previous year's citation count divided by the previous year's citation count.
#
# Start computing the rate of change from __the first year in which a citation is recorded__. This
# approach ignores the time lag between publication and first citation. It likely inflates citation
# change rates but it simplifies the code that you must write since it reduces though
# _does not eliminate_ handling years that feature zero (`0`) counts that can trigger
# `ZeroDivisionError` exceptions.

# %%
def get_citation_change_rates(citations):
    """
    Calculate the year-over-year rate of change in a publication's citation count commencing with
    the first year that a citation is recorded. The rate of change for the current year is
    calculated as follows:

    rate_of_change = (current_year_count - previous_year_count) / previous_year_count

    If a publication has yet to accrue citations, the function returns an empty list [] and an
    average rate of change of 0. Otherwise, the function returns a list of year-over-year change
    rates.

    Parameters:
        citations (list): list of dictionaries containing a publication's annual citation counts

    Returns:
        list: list of year-to-year rate changes.
    """

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.2 Implement `calc_avg_citation_change_rate()` [1 pt]
#
# Next, turn your attention to the function `calc_avg_citation_change_rate()`. This function must
# compute the _average_ citation count rate of change for a given publication. The function delegates
# to `get_citation_change_rates()` the task of assembling a list of citation change rates for a given
# publication. Once the function has obtained the list of citation change rates, it computes the
# average rate of change and returns the computed value to the caller.

# %%
def calc_avg_citation_change_rate(publication):
    """Calculate the average rate of change in a publication's year-over-year citation counts. The
    function delegates to the function < get_citation_rates_of_change > the task of calculating the
    rate of change for each year.

    Parameters:
        publication (dict): representation of a publication

    Returns:
        float: average rate of change in citation counts
    """

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 5.3 Top 5 [1 pt]
#
# Now put the two functions to work. Loop over the `publications` list. Inside the loop block, call
# `calc_avg_citation_change_rate()` and pass it the current publication. Assign the return value to a
# new publication key-value pair named "Citations Avg Change Rate". After the loop terminates, sort
# the list ofpublication dictionaries by "Citations Avg Change Rate" (descending order) and then by
# "Title" (ascending order) values.
#
# Slice the list to return the top five (`5`) publications with the highest average citation change
# rates and assign the new list to a variable named `top_5_avg_cits`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell

# %% [markdown]
# Uncomment the `print()` function and inspect the first five dictionaries in the sorted list.

# %%
# for pub in top_5_avg_cits:
#     print(
#         f"\n{pub['Title']} ({pub['Year']}):\n"
#         "Average year-over-year citation count rate of change: "
#         f"{round(pub['Citations'], 3)}"
#     )

# %% [markdown]
# ### 5.4 "Enquiring Minds" rules
#
# Paul's coauthored article "Enquiring Minds" continues to impress with an average year-over-year
# citation count rate of change of `1.487` for the period `2015` to `2023`. Interestingly, neither
# Paul's recommender systems nor reputation systems publications is included `top_5_avg_cits` list.
# Further analysis is required to better understand the degree of influence "Enquiring Minds" and
# other `top_5_avg_cits` publications hold on the scholarly imagination and research community.
#
# ### 5.5 Write to file [1 pt]
#
# Write the list `top_5_avg_cits` to a JSON file named
# `stu-resnick-citations-top_05_avg_change_rate.json`. Check your work against the fixture
# data file named `fxt-resnick-citations-top_05_avg_change_rate.json`. The two files _must_
# match line for line.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# hidden tests are within this cell
