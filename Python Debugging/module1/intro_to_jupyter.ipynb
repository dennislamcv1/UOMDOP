# %% [markdown]
# # Welcome to a Jupyter notebook
# Let's get to know the Jupyter notebook together. Jupyter notebooks are a neat way to combine writing, code, and even figures. We'll use this notebook to learn some important features and concepts.

# %%
# This cell contains Python code.
print("Howdy, welcome to your Jupyter notebook.")

# %% [markdown]
# You can do a limitless variety of computations in Python cells. Here's a short example using only base Python. Let's say we have a list that represents the dog breeds that are currently at a dog park, and we want to know how many retrievers are there.

# %%
dogs_at_park = ["retriever", "spaniel", "retriever", "labrador", "shepherd", "terrier", "shepherd", "retriever"]
dogs_at_park.count("retriever")
# Out:
# 3

# %% [markdown]
# We can also use Python cells to create expressive and dynamic visuals that render right in the notebook. Let's replicate an example from the [Seaborn visualization gallery](https://seaborn.pydata.org/examples/layered_bivariate_plot.html).

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# ## Tips and tricks
# Here are a few things to keep in mind about working in Jupyter.

# %% [markdown]
# ### Use the right kind of cell.
# What's wrong with this code block below? Why won't it work?

# %% [markdown]
# # Define a function to calculate the square of a number
# def square(num):
#     return num ** 2
#
# # Call the function and print the result
# square(5)

# %% [markdown]
# ### It's not enough to write code- you have to run it.
# One of the trickiest aspects of Jupyter notebooks for beginners is _making sure you run your code._ It's not enough to _write_ code in a code cell. It has to be executed! You can do that by clicking the "play" icon on a cell.
#
# If you only run the code in the second cell below without running the first, you'll get an error- because as far as Python knows, the variable `grocery_list` has never been created.

# %%
grocery_list = ["orange", "plum", "tangerine"]

# %%
grocery_list[1]

# %% [markdown]
# ### Turn on line-numbers for easier debugging.
# Having visible line numbers will help you debug errors in large blocks of Python code. You can make sure these are turned on by checking the "Settings" for your cells.

# %%
def greet(name):
    return f"Hello, {name}!"

def add(a, b):
    return a + b

add(5,3)
greet("Anthony")
# Out:
# 'Hello, Anthony!'

# %% [markdown]
# You might also notice something about the printed outputs above- do you see all the outputs you expect? Is anything missing?

# %% [markdown]
# ### Remember that objects and functions you define persist until you restart your session.
# Earlier, we created an object that stores dog breeds currently visiting a dog park. We can still refer to it several cells later.

# %%
dogs_at_park[0]
# Out:
# 'retriever'

# %% [markdown]
# There are several ways to restart the _kernel_, the Python session you are currently using. Closing and reopening the notebook is one way. You can also use the "Restart Session" option in the dropdown "Runtime" menu.
